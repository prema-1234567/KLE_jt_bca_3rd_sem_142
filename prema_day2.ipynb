# %%
numbers=[10,20,30,40,50]
print(numbers[0])
print(numbers[-1])
print(numbers[1:4])
numbers.append(55)
print(numbers)
# Out:
# 10
# 50
# [20, 30, 40]
# [10, 20, 30, 40, 50, 55]

# %%
type(numbers)
# Out:
# list

# %%
numbers[2]=40
numbers
# Out:
# [10, 20, 40, 40, 50, 55]

# %%
numbers.count(40)
# Out:
# 2

# %%
numbers.index(50)
# Out:
# 3

# %%
numbers.remove(55)
print(numbers)
# Out:
# [10, 40, 40]

# %%
numbers.insert(4,21)
print(numbers)
# Out:
# [10, 40, 40, 21]

# %%
numbers
# Out:
# [10, 40, 40, 21]

# %%
numbers.extend([10,40])
print(numbers)
# Out:
# [10, 40, 40, 21, 10, 40]

# %%
numbers.append([12,43,65,77])
print(numbers)
# Out:
# [10, 40, 40, 21, 10, 40, [12, 43, 65, 77], [12, 43, 65, 77]]

# %%
numbers[6]
# Out:
# [12, 43, 65, 77]

# %%
numbers[6][0]
# Out:
# 12

# %%
numbers[6][3]
# Out:
# 77

# %%
numbers
# Out:
# [10, 10, 21, 40, 40, 40, [12, 43, 65, 77], [12, 43, 65, 77]]

# %%
example=[1,2,1,3,2,4]
example.sort()
print(example)
# Out:
# [1, 1, 2, 2, 3, 4]

# %%
example=[1,2,1,3,2,4]
example.reverse()
print(example)
# Out:
# [4, 2, 3, 1, 2, 1]

# %%
new=example.copy()
new
# Out:
# [4, 2, 3, 1, 2, 1]

# %%
numbers.clear()
numbers
# Out:
# []

# %%
numbers=(10,20,30,20)
print(numbers.count(20))
print(numbers.index(30))
print(numbers[1:3])
print(type(numbers))
print(len(numbers))
print(sorted(numbers))
print(numbers.index(20))
# Out:
# 2
# 2
# (20, 30)
# <class 'tuple'>
# 4
# [10, 20, 20, 30]
# 1

# %%
set={10,20,30,40,50}
set
# Out:
# {10, 20, 30, 40, 50}

# %%
set.add(33)
set
# Out:
# {10, 20, 30, 33, 40, 50}

# %%
set.remove(10)
set
# Out:
# {20, 30, 33, 40, 50}

# %%
print(type(set))
# Out:
# <class 'set'>

# %%
print(len(set))
# Out:
# 5

# %%
print(10 not in set)
numbers
# Out:
# True
# (10, 20, 30, 20)

# %%
set.clear()
set
# Out:
# set()

# %%
A={1,2,3,4,5,6,7,8}

# %%
print(set.index(20))
set
# Out:
# 1
# (10, 20, 30, 40)

# %%
A={1,2,3,4,5,6}
B={9,8,7,6,6,5}
print(A.union(B) )
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
print( A | B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
print(A&B)
# Out:
# {5, 6}

# %%
print(A.difference(B) )
# Out:
# {1, 2, 3, 4}

# %%
print(A^B)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
a,b,c=10,15,30
if a>b:
  if a>c:
    print(" a is a largest number")
  else:
    print("c is largest ")
else:
   if b>c:
    print(" b is largest number")
   else:
    print("c is largest")
# Out:
# c is largest

# %%
day=int(input("Enter the day number:"))
match day:
  case 1:print("monday")
  case 2:print("tuesday")
  case 3:print("wednesday")
  case 4:print("thursday")
  case 5:print("friday")
  case 6:print("saturday")
  case 1:print("msunday")
  case _ :print("invalid day")

# %%
while num!=0:
  rem=num+rem*rem*rem
