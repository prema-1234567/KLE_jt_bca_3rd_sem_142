# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# python second pgm

# %%
print("*"*3)
# Out:
# ***

# %%
print("*" * 3, sep="\n")
# Out:
# ***

# %%
name="Raimanabi"
print(name)
# Out:
# Raimanabi
